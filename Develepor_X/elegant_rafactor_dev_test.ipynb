# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Rock_Genetics.rock_genetic_helper import *

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
#Lob.genotype = Genome.instantiate_genotype(Rock_gene_dict)
# Out:
# Rock(id=1, name='Lobster Boi', sex=<Sex.MALE: 'male'>, genotype=Genome(genes={}), parent_ids=[], generation=0, status=<RockStatus.ACTIVE: 'active'>, image_path=None, value=None, is_market=False)

# %%
GENE_SPECS["arms"].option_for_allele(2)

#GENE_SPECS["eyes"].state_for_key(2)
# Essentially only used for dosage genes!

#GENE_SPECS["arms"].special_states[(0,1)]
#GENE_SPECS["eye_color"].option_for_allele(0)
# Out:
# TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)

# %%
a = Allele(0)
b = Allele(1)

dose = 0
dose += 1 if a.value == 1 else 0
dose += 1 if b.value == 1 else 0

dose
# Out:
# 1

# %%
rock_parent_a = Rock(1, "lobber", sex = Sex.MALE)
rock_parent_a.genotype = Genome.instantiate_genotype(genome_spec_list = GENE_SPECS)
#rock_parent_b = Rock(2, "lobba", sex = Sex.FEMALE)
#rock_parent_b.genotype = Genome.instantiate_genotype(genome_spec_list = GENE_SPECS)

print(rock_parent_a.genotype)

#for gene in rock_parent_a.genotype.genes:
#    print(rock_parent_a.genotype.genes[gene].allele_a)
##    print(rock_parent_a.genotype.genes[gene].allele_b)
##    print(rock_parent_a.genotype.genes[gene].phenotype)


#rock_parent_b.genotype

#rock_child = Rock(id = 3, name = "lobbera", sex = Sex.MALE)
#rock_child.genotype = Genome.instantiate_genotype(
#    genome_spec_list = GENE_SPECS,
#    parent_a = rock_parent_a,
#    parent_b = rock_parent_b
#    )

#print(rock_child.genotype)


#Genome.instantiate_genotype(genome_spec_list = GENE_SPECS)
# Out:
# Genome(genes={'shape': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='shape', dominance_type='dominance', money_value=-2, phenotype='oblong'), 'size': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='size', dominance_type='dominance', money_value=-2, phenotype='missized'), 'color': GenePair(allele_a=Allele(value=6), allele_b=Allele(value=6), name_of_gene='color', dominance_type='body_color_dominance', money_value=-1, phenotype='patchwork'), 'eyes': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='eyes', dominance_type='dosage', money_value=2, phenotype='double eye'), 'brows': GenePair(allele_a=Allele(value=3), allele_b=Allele(value=3), name_of_gene='brows', dominance_type='dominance', money_value=-1, phenotype='unibrows'), 'mouths': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='mouths', dominance_type='dominance', money_value=-1, phenotype='smeagol'), 'noses': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='noses', dominance_type='dominance', money_value=-1, phenotype='concave'), 'arms': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=2), name_of_gene='arms', dominance_type='arms_dominance', money_value=2, phenotype='muscle arms'), 'crowns': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='crowns', dominance_type='dominance', money_value=-1, phenotype='indent'), 'wings': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='wings', dominance_type='dominance', money_value=2, phenotype='wings'), 'halos': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='halos', dominance_type='dominance', money_value=2, phenotype='halos'), 'horns': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='horns', dominance_type='dominance', money_value=2, phenotype='horns'), 'wrinkles': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='wrinkles', dominance_type='dominance', money_value=2, phenotype='wrinkles'), 'fuzz': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='fuzz', dominance_type='dosage', money_value=2, phenotype='spiky'), 'hair': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='hair', dominance_type='dosage', money_value=2, phenotype='double hair'), 'facial_hair': GenePair(allele_a=Allele(value=6), allele_b=Allele(value=6), name_of_gene='facial_hair', dominance_type='dominance', money_value=-2, phenotype='sol'), 'freckles': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='freckles', dominance_type='dominance', money_value=2, phenotype='freckles'), 'stones': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='stones', dominance_type='dominance', money_value=2, phenotype='stones'), 'tails': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='tails', dominance_type='dominance', money_value=2, phenotype='tails'), 'eye_color': GenePair(allele_a=Allele(value=8), allele_b=Allele(value=8), name_of_gene='eye_color', dominance_type='dominance', money_value=-3, phenotype='callus'), 'hair_color': GenePair(allele_a=Allele(value=6), allele_b=Allele(value=6), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=-2, phenotype='blue'), 'ears': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='ears', dominance_type='dominance', money_value=-1, phenotype='goblin'), 'hair_texture': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='hair_texture', dominance_type='dominance', money_value=2, phenotype='curly'), 'splitting': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=2), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype='spore')})
