# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)

from Rock_Genetics.rock_genetic_helper import *
# Out:
# c:\Users\xavie\Desktop\rock_game

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
# Out:
# Rock(id=1, name='Lobster Boi', sex=<Sex.MALE: 'male'>, genotype=Genome(genes={}), death_genes=Genome(genes={}), parent_ids=[], generation=0, status=<RockStatus.ACTIVE: 'active'>, has_split=False, checked_craisen=False, death_reason=None, image_path=None, value=0, sell_value=0, score_value=0, is_market=False)

# %%
GENE_SPECS["arms"].option_for_allele(2)

#GENE_SPECS["eyes"].state_for_key(2)
# Essentially only used for dosage genes!

#GENE_SPECS["arms"].special_states[(0,1)]
#GENE_SPECS["eye_color"].option_for_allele(0)
# Out:
# TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)

# %%
factorio = GenomeFactory()
espresso = ExpressionEngine()
valuo = ValueCalculator()

Rock1 = Rock(
    id=1, 
    name="bruh", 
    sex=Sex.MALE, 
    genotype=factorio.make_random_rock_genome(),
    death_genes= factorio.make_death_genes(),
    )

Rock2 = Rock(
    id=2, 
    name="bruha", 
    sex=Sex.FEMALE, 
    genotype=factorio.make_random_rock_genome(),
    death_genes= factorio.make_death_genes(),
)

print(Rock1.genotype)
print(Rock1.genotype.genes)

#Rock1 = espresso.instantiate_phenotype(rock=Rock1, genome_spec_list=GENE_SPECS)

#print(Rock1)

#Rock1 = valuo.set_rock_value(rock=Rock1,genome_spec_list=GENE_SPECS)

#print(Rock1)


Rock_Child = valuo.set_rock_value(
    rock = espresso.instantiate_phenotype(
        rock = Rock(
            id = 3, 
            name = "bruhbruh", 
            sex = Sex.MALE, 
            genotype = factorio.make_child_rock_genome_from_parents(
                parent_a = Rock1, 
                parent_b = Rock2
                )
            )
        )
    )


print(Rock_Child.genotype.print_genes())
# Out:
# Genome(genes={'shape': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=3), name_of_gene='shape', dominance_type='dominance', money_value=0, phenotype=None), 'size': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='size', dominance_type='dominance', money_value=0, phenotype=None), 'color': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=1), name_of_gene='color', dominance_type='body_color_dominance', money_value=0, phenotype=None), 'eyes': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eyes', dominance_type='dosage', money_value=0, phenotype=None), 'brows': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='brows', dominance_type='dominance', money_value=0, phenotype=None), 'mouths': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='mouths', dominance_type='dominance', money_value=0, phenotype=None), 'noses': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='noses', dominance_type='dominance', money_value=0, phenotype=None), 'arms': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='arms', dominance_type='arms_dominance', money_value=0, phenotype=None), 'crowns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='crowns', dominance_type='dominance', money_value=0, phenotype=None), 'wings': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wings', dominance_type='dominance', money_value=0, phenotype=None), 'halos': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='halos', dominance_type='dominance', money_value=0, phenotype=None), 'horns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='horns', dominance_type='dominance', money_value=0, phenotype=None), 'wrinkles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wrinkles', dominance_type='dominance', money_value=0, phenotype=None), 'fuzz': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='fuzz', dominance_type='dosage', money_value=0, phenotype=None), 'hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair', dominance_type='dosage', money_value=0, phenotype=None), 'facial_hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='facial_hair', dominance_type='dominance', money_value=0, phenotype=None), 'freckles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='freckles', dominance_type='dominance', money_value=0, phenotype=None), 'stones': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='stones', dominance_type='dominance', money_value=0, phenotype=None), 'tails': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='tails', dominance_type='dominance', money_value=0, phenotype=None), 'eye_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eye_color', dominance_type='dominance', money_value=0, phenotype=None), 'hair_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=0, phenotype=None), 'ears': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='ears', dominance_type='dominance', money_value=0, phenotype=None), 'hair_texture': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_texture', dominance_type='dominance', money_value=0, phenotype=None), 'splitting': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=0), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype=None)})
# {'shape': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=3), name_of_gene='shape', dominance_type='dominance', money_value=0, phenotype=None), 'size': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='size', dominance_type='dominance', money_value=0, phenotype=None), 'color': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=1), name_of_gene='color', dominance_type='body_color_dominance', money_value=0, phenotype=None), 'eyes': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eyes', dominance_type='dosage', money_value=0, phenotype=None), 'brows': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='brows', dominance_type='dominance', money_value=0, phenotype=None), 'mouths': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='mouths', dominance_type='dominance', money_value=0, phenotype=None), 'noses': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='noses', dominance_type='dominance', money_value=0, phenotype=None), 'arms': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='arms', dominance_type='arms_dominance', money_value=0, phenotype=None), 'crowns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='crowns', dominance_type='dominance', money_value=0, phenotype=None), 'wings': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wings', dominance_type='dominance', money_value=0, phenotype=None), 'halos': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='halos', dominance_type='dominance', money_value=0, phenotype=None), 'horns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='horns', dominance_type='dominance', money_value=0, phenotype=None), 'wrinkles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wrinkles', dominance_type='dominance', money_value=0, phenotype=None), 'fuzz': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='fuzz', dominance_type='dosage', money_value=0, phenotype=None), 'hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair', dominance_type='dosage', money_value=0, phenotype=None), 'facial_hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='facial_hair', dominance_type='dominance', money_value=0, phenotype=None), 'freckles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='freckles', dominance_type='dominance', money_value=0, phenotype=None), 'stones': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='stones', dominance_type='dominance', money_value=0, phenotype=None), 'tails': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='tails', dominance_type='dominance', money_value=0, phenotype=None), 'eye_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eye_color', dominance_type='dominance', money_value=0, phenotype=None), 'hair_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=0, phenotype=None), 'ears': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='ears', dominance_type='dominance', money_value=0, phenotype=None), 'hair_texture': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_texture', dominance_type='dominance', money_value=0, phenotype=None), 'splitting': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=0), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype=None)}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 39
#      35         rock = Rock(
#      36             id = 3,
#      37             name = "bruhbruh",
#      38             sex = Sex.MALE,
# ---> 39             genotype = factorio.make_child_rock_genome_from_parents(
#      40                 parent_a = Rock1,
#      41                 parent_b = Rock2
#      42                 )
#
# TypeError: GenomeFactory.make_child_rock_genome_from_parents() missing 1 required positional argument: 'mutation_chance'

# %%
print(Rock1.death_genes.genes)
print(Rock2.death_genes.genes)

Rock_Child = valuo.set_rock_value(
    rock = espresso.instantiate_phenotype(
        rock = Rock(
            id = 3, 
            name = "bruhbruh", 
            sex = Sex.MALE, 
            genotype = factorio.make_child_rock_genome_from_parents(
                parent_a = Rock1, 
                parent_b = Rock2
                ),
            death_genes = factorio.inherit_death_genes(
                parent_a= Rock1,
                parent_b= Rock2,
            ),
            )
        )
    )

Rock_Child.death_genes.genes

# %%
Rock1.change_status(new_status= RockStatus.BRED)
Rock1

# %%
spore_clone_count = 4
for spore_clone in range(1 + spore_clone_count):
    print(spore_clone)

# %%
spores = 4
for spo in range(spores):
    print(spo)

# %%
child_bred_in_generation = [1,2,3]

new_id = 0

if child_bred_in_generation:
    new_id = 1 + len(child_bred_in_generation)

print(new_id)
print(type(new_id))

# %%
child_bred_in_generation = [1]

print(len(child_bred_in_generation))

# %%
list_cho =[]

spore_maybe = random.randint(1,4)

for cho in range(spore_maybe):
    list_cho.append(random.choice([Rock1.id, Rock2.id]))

print(list_cho)
bro_list = []

if len(list_cho) > 1:   
    list_cho.pop(0)
    for spo in list_cho:
        bro_list.append(spo)


print(bro_list)

# %%
inputs = ["death_chance", "spore_count", "spore_death_chance"]

for chance in inputs:
    if chance == None:
        inputs[chance] = "ham"

print(inputs)

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)

import Rock_Genetics.rock_genetic_helper as genetics
import Rock_Breeding.rock_breeding_helper as breeding
# Out:
# c:\Users\xavie\Desktop\rock_game

# %%
factorio = genetics.GenomeFactory()
espresso = genetics.ExpressionEngine()
valuo = genetics.ValueCalculator()

breedo = breeding.BreedingMaster(
    GenomeFactory = factorio,
    ExpressionEngine = espresso,
    ValueCalculator = valuo,
)

Rock1 = genetics.Rock(
    id=1, 
    name=breedo.random_rock_name(genetics.Sex.MALE), 
    sex=genetics.Sex.MALE, 
    genotype = factorio.make_random_rock_genome(),
    death_genes = factorio.make_death_genes(),
    generation = 0
    )

Rock1 = valuo.set_rock_value(Rock1)

Rock2 = genetics.Rock(
    id=2, 
    name=breedo.random_rock_name(genetics.Sex.FEMALE), 
    sex=genetics.Sex.FEMALE, 
    genotype = factorio.make_random_rock_genome(),
    death_genes =  factorio.make_death_genes(),
    generation = 0
)

Rock2 = valuo.set_rock_value(Rock2)

parent_clutch = breedo.breed_parent_set(
    parent_a = Rock1,
    parent_b = Rock2,
    next_id = 3,
    child_generation = 1,
)

print(f"{Rock1.name.full_name}, {Rock1.value} and {Rock2.name.full_name}, {Rock2.value} had:")

for child in parent_clutch:
    print(f"{child.id} is {child.name.full_name}: value {child.value}, sellable: {child.sell_value}")
# Out:
# Pebmond, 1 and Marbmond, 2 had:
# 3 is Quartstone: value 4, sellable: 4
# 4 is Feldble: value 2, sellable: 2
# 5 is Garngrim: value 1, sellable: 1
# 6 is Grumkins: value 5, sellable: 5
# 7 is Cobbyx: value 4, sellable: 4

# %%
for child in parent_clutch:
    print(f"value: {child.value}, phenotype: {child.genotype.print_genes()}")
# Out:
# shape: 0 and 0 as: circle worth 0
#
# size: 1 and 0 as: medium worth 0
#
# color: 1 and 6 as: black worth 0
#
# eyes: 1 and 0 as: eye worth 1
#
# brows: 0 and 0 as: n/a worth 0
#
# mouths: 0 and 0 as: n/a worth 0
#
# noses: 2 and 3 as: honk worth 2
#
# arms: 0 and 0 as: n/a worth 0
#
# crowns: 0 and 0 as: n/a worth 0
#
# wings: 0 and 1 as: n/a worth 0
#
# halos: 0 and 0 as: n/a worth 0
#
# horns: 0 and 0 as: n/a worth 0
#
# wrinkles: 0 and 0 as: n/a worth 0
#
# fuzz: 0 and 0 as: n/a worth 0
#
# hair: 1 and 0 as: hair worth 1
#
# facial_hair: 0 and 3 as: n/a worth 0
#
# freckles: 0 and 0 as: n/a worth 0
#
# stones: 0 and 0 as: n/a worth 0
#
# tails: 0 and 0 as: n/a worth 0
#
# eye_color: 0 and 0 as: white worth 0
#
# hair_color: 0 and 5 as: white worth 0
#
# ears: 0 and 0 as: n/a worth 0
#
# hair_texture: 1 and 0 as: straight worth 0
#
# splitting: 0 and 0 as: n/a worth 0
#
# value: 5, phenotype: None
# shape: 1 and 3 as: oval worth -1
#
# size: 1 and 0 as: medium worth 0
#
# color: 1 and 6 as: black worth 0
#
# eyes: 0 and 0 as: n/a worth 0
#
# brows: 0 and 0 as: n/a worth 0
#
# mouths: 0 and 0 as: n/a worth 0
#
# noses: 2 and 3 as: honk worth 2
#
# arms: 0 and 0 as: n/a worth 0
#
# crowns: 0 and 1 as: n/a worth 0
#
# wings: 0 and 0 as: n/a worth 0
#
# halos: 0 and 0 as: n/a worth 0
#
# horns: 0 and 0 as: n/a worth 0
#
# wrinkles: 0 and 0 as: n/a worth 0
#
# fuzz: 0 and 0 as: n/a worth 0
#
# hair: 1 and 0 as: hair worth 1
#
# facial_hair: 0 and 0 as: n/a worth 0
#
# freckles: 0 and 0 as: n/a worth 0
#
# stones: 0 and 0 as: n/a worth 0
#
# tails: 0 and 0 as: n/a worth 0
#
# eye_color: 0 and 6 as: white worth 0
#
# hair_color: 0 and 5 as: white worth 0
#
# ears: 0 and 0 as: n/a worth 0
#
# hair_texture: 1 and 0 as: straight worth 0
#
# splitting: 0 and 0 as: n/a worth 0
#
# value: 3, phenotype: None
# shape: 0 and 3 as: circle worth 0
#
# size: 0 and 0 as: medium worth 0
#
# color: 1 and 6 as: black worth 0
#
# eyes: 0 and 0 as: n/a worth 0
#
# brows: 0 and 0 as: n/a worth 0
#
# mouths: 0 and 0 as: n/a worth 0
#
# noses: 2 and 3 as: honk worth 2
#
# arms: 0 and 0 as: n/a worth 0
#
# crowns: 0 and 0 as: n/a worth 0
#
# wings: 0 and 0 as: n/a worth 0
#
# halos: 0 and 0 as: n/a worth 0
#
# horns: 0 and 0 as: n/a worth 0
#
# wrinkles: 0 and 1 as: n/a worth 0
#
# fuzz: 0 and 0 as: n/a worth 0
#
# hair: 1 and 0 as: hair worth 1
#
# facial_hair: 0 and 0 as: n/a worth 0
#
# freckles: 0 and 0 as: n/a worth 0
#
# stones: 0 and 0 as: n/a worth 0
#
# tails: 0 and 0 as: n/a worth 0
#
# eye_color: 0 and 0 as: white worth 0
#
# hair_color: 0 and 0 as: white worth 0
#
# ears: 0 and 3 as: n/a worth 0
#
# hair_texture: 0 and 0 as: straight worth 0
#
# splitting: 0 and 0 as: n/a worth 0
#
# value: 4, phenotype: None
# shape: 1 and 0 as: circle worth 0
#
# size: 0 and 0 as: medium worth 0
#
# color: 1 and 6 as: black worth 0
#
# eyes: 1 and 0 as: eye worth 1
#
# brows: 2 and 2 as: eyehair worth 2
#
# mouths: 1 and 1 as: mouth worth 1
#
# noses: 3 and 3 as: holes worth 3
#
# arms: 0 and 0 as: n/a worth 0
#
# crowns: 0 and 0 as: n/a worth 0
#
# wings: 0 and 0 as: n/a worth 0
#
# halos: 0 and 0 as: n/a worth 0
#
# horns: 0 and 0 as: n/a worth 0
#
# wrinkles: 0 and 0 as: n/a worth 0
#
# fuzz: 0 and 0 as: n/a worth 0
#
# hair: 1 and 0 as: hair worth 1
#
# facial_hair: 0 and 3 as: n/a worth 0
#
# freckles: 0 and 0 as: n/a worth 0
#
# stones: 0 and 0 as: n/a worth 0
#
# tails: 0 and 0 as: n/a worth 0
#
# eye_color: 0 and 6 as: white worth 0
#
# hair_color: 2 and 5 as: brown worth 1
#
# ears: 4 and 3 as: ogre worth 3
#
# hair_texture: 1 and 0 as: straight worth 0
#
# splitting: 0 and 0 as: n/a worth 0
#
# value: 13, phenotype: None

# %% [markdown]
# ## Rock Drawing Refactor Flow Test
#
# This section tests the new `RockRenderContext` + `DrawMachine` drawing flow without touching breeding/game-state code.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'Develepor_X':
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import matplotlib.pyplot as plt
from importlib import reload

import Rock_Genetics.rock_genetic_helper as genetics
import Rock_Drawing.rock_drawing_helper as drawing

genetics = reload(genetics)
drawing = reload(drawing)

print('loaded', drawing.RockRenderContext.__name__, drawing.DrawMachine.__name__)
# Out:
# loaded RockRenderContext DrawMachine

# %%
def make_forced_rock(rock_id=100, sex=genetics.Sex.MALE, choices=None, given='Refactor'):
    choices = choices or {}
    genes = {}

    for gene_name, spec in genetics.GENE_SPECS.items():
        allele_value = choices.get(gene_name, min(spec.options.keys()))
        genes[gene_name] = genetics.GenePair(
            allele_a=genetics.Allele(allele_value),
            allele_b=genetics.Allele(allele_value),
            name_of_gene=gene_name,
            dominance_type=spec.expression_rule,
        )

    rock = genetics.Rock(
        id=rock_id,
        sex=sex,
        name=genetics.RockName(given=given),
        genotype=genetics.Genome(genes),
    )

    genetics.ExpressionEngine().instantiate_phenotype(rock)
    return rock

def make_random_rock(rock_id=101, sex=genetics.Sex.MALE, given='Random'):
    genome = genetics.GenomeFactory().make_random_rock_genome()
    rock = genetics.Rock(
        id=rock_id,
        sex=sex,
        name=genetics.RockName(given=given),
        genotype=genome,
    )
    genetics.ExpressionEngine().instantiate_phenotype(rock)
    return rock

# %%
feature_choices = {
    'shape': 3,
    'size': 0,
    'color': 6,
    'eyes': 1,
    'brows': 3,
    'mouths': 4,
    'noses': 4,
    'arms': 2,
    'crowns': 3,
    'wings': 1,
    'halos': 1,
    'horns': 1,
    'wrinkles': 1,
    'fuzz': 1,
    'hair': 1,
    'facial_hair': 6,
    'freckles': 1,
    'stones': 1,
    'tails': 1,
    'eye_color': 6,
    'hair_color': 5,
    'ears': 4,
    'hair_texture': 1,
    'splitting': 0,
}

rocks = [
    make_random_rock(rock_id=201, given='Random'),
    make_forced_rock(rock_id=202, choices=feature_choices, given='Feature Stack'),
]

fig, axes = plt.subplots(1, len(rocks), figsize=(5 * len(rocks), 5))
if len(rocks) == 1:
    axes = [axes]

for ax, rock in zip(axes, rocks):
    machine = drawing.DrawMachine(rock=rock, ax=ax, normalize_size=True)
    machine.draw()
    print('rock', rock.id, drawing.get_visual_phenotype(rock))
    print('face slots', machine.ctx.face_layout.slots)

plt.tight_layout()
plt.show()
# Out:
# rock 201 {'gender': 'Male', 'is_craisen': False, 'shape_values': [0, 0], 'shape_alleles': ['circle', 'circle'], 'shape': 'circle', 'size_values': [2, 0], 'size_alleles': ['small', 'medium'], 'size': 'medium', 'color_values': [0, 1], 'color_alleles': ['white', 'black'], 'color': 'silver', 'eyes_values': [0, 0], 'eyes_alleles': ['inactive', 'inactive'], 'eyes': 'n/a', 'brows_values': [1, 0], 'brows_alleles': ['brows', 'n/a'], 'brows': 'n/a', 'mouths_values': [0, 0], 'mouths_alleles': ['n/a', 'n/a'], 'mouths': 'n/a', 'noses_values': [4, 2], 'noses_alleles': ['concave', 'honk'], 'noses': 'honk', 'arms_values': [0, 0], 'arms_alleles': ['n/a', 'n/a'], 'arms': 'n/a', 'crowns_values': [0, 0], 'crowns_alleles': ['n/a', 'n/a'], 'crowns': 'n/a', 'wings_values': [0, 0], 'wings_alleles': ['n/a', 'n/a'], 'wings': 'n/a', 'halos_values': [1, 0], 'halos_alleles': ['halos', 'n/a'], 'halos': 'n/a', 'horns_values': [0, 0], 'horns_alleles': ['n/a', 'n/a'], 'horns': 'n/a', 'wrinkles_values': [0, 0], 'wrinkles_alleles': ['n/a', 'n/a'], 'wrinkles': 'n/a', 'fuzz_values': [0, 0], 'fuzz_alleles': ['inactive', 'inactive'], 'fuzz': 'n/a', 'hair_values': [0, 0], 'hair_alleles': ['inactive', 'inactive'], 'hair': 'n/a', 'facial_hair_values': [1, 4], 'facial_hair_alleles': ['goatee', 'curly'], 'facial_hair': 'goatee', 'freckles_values': [0, 0], 'freckles_alleles': ['n/a', 'n/a'], 'freckles': 'n/a', 'stones_values': [0, 0], 'stones_alleles': ['n/a', 'n/a'], 'stones': 'n/a', 'tails_values': [0, 0], 'tails_alleles': ['n/a', 'n/a'], 'tails': 'n/a', 'eye_color_values': [6, 0], 'eye_color_alleles': ['evil', 'white'], 'eye_color': 'white', 'hair_color_values': [0, 1], 'hair_color_alleles': ['white', 'black'], 'hair_color': 'silver', 'ears_values': [0, 4], 'ears_alleles': ['n/a', 'goblin'], 'ears': 'n/a', 'hair_texture_values': [0, 0], 'hair_texture_alleles': ['straight', 'straight'], 'hair_texture': 'straight', 'splitting_values': [0, 0], 'splitting_alleles': ['n/a', 'n/a'], 'splitting': 'n/a', 'eyes_count': 0, 'fuzz_count': 0, 'hair_count': 0, 'normal_arm_pairs': 0, 'muscle_arm_pairs': 0, 'normal_arm_count': 0, 'muscle_arm_count': 0}
# face slots {'nose': FeatureSlot(name='nose', nx=0.5, ny=0.47, scale=0.95), 'facial_hair': FeatureSlot(name='facial_hair', nx=0.5, ny=0.17, scale=1.05)}
# rock 202 {'gender': 'Male', 'is_craisen': False, 'shape_values': [3, 3], 'shape_alleles': ['triangle', 'triangle'], 'shape': 'triangle', 'size_values': [0, 0], 'size_alleles': ['medium', 'medium'], 'size': 'medium', 'color_values': [6, 6], 'color_alleles': ['patchwork', 'patchwork'], 'color': 'patchwork', 'eyes_values': [1, 1], 'eyes_alleles': ['active', 'active'], 'eyes': 'double eye', 'brows_values': [3, 3], 'brows_alleles': ['unibrows', 'unibrows'], 'brows': 'unibrows', 'mouths_values': [4, 4], 'mouths_alleles': ['smeagol', 'smeagol'], 'mouths': 'smeagol', 'noses_values': [4, 4], 'noses_alleles': ['concave', 'concave'], 'noses': 'concave', 'arms_values': [2, 2], 'arms_alleles': ['muscle arms', 'muscle arms'], 'arms': 'two pair muscle arms', 'crowns_values': [3, 3], 'crowns_alleles': ['large', 'large'], 'crowns': 'large', 'wings_values': [1, 1], 'wings_alleles': ['wings', 'wings'], 'wings': 'wings', 'halos_values': [1, 1], 'halos_alleles': ['halos', 'halos'], 'halos': 'halos', 'horns_values': [1, 1], 'horns_alleles': ['horns', 'horns'], 'horns': 'horns', 'wrinkles_values': [1, 1], 'wrinkles_alleles': ['wrinkles', 'wrinkles'], 'wrinkles': 'wrinkles', 'fuzz_values': [1, 1], 'fuzz_alleles': ['active', 'active'], 'fuzz': 'spiky', 'hair_values': [1, 1], 'hair_alleles': ['active', 'active'], 'hair': 'double hair', 'facial_hair_values': [6, 6], 'facial_hair_alleles': ['sol', 'sol'], 'facial_hair': 'sol', 'freckles_values': [1, 1], 'freckles_alleles': ['freckles', 'freckles'], 'freckles': 'freckles', 'stones_values': [1, 1], 'stones_alleles': ['stones', 'stones'], 'stones': 'stones', 'tails_values': [1, 1], 'tails_alleles': ['tails', 'tails'], 'tails': 'tails', 'eye_color_values': [6, 6], 'eye_color_alleles': ['evil', 'evil'], 'eye_color': 'evil', 'hair_color_values': [5, 5], 'hair_color_alleles': ['pink', 'pink'], 'hair_color': 'pink', 'ears_values': [4, 4], 'ears_alleles': ['goblin', 'goblin'], 'ears': 'goblin', 'hair_texture_values': [1, 1], 'hair_texture_alleles': ['curly', 'curly'], 'hair_texture': 'curly', 'splitting_values': [0, 0], 'splitting_alleles': ['n/a', 'n/a'], 'splitting': 'n/a', 'eyes_count': 2, 'fuzz_count': 2, 'hair_count': 2, 'normal_arm_pairs': 0, 'muscle_arm_pairs': 2, 'normal_arm_count': 0, 'muscle_arm_count': 4}
# face slots {'brows': FeatureSlot(name='brows', nx=0.5, ny=0.705, scale=0.95), 'eyes': FeatureSlot(name='eyes', nx=0.5, ny=0.565, scale=1.0), 'nose': FeatureSlot(name='nose', nx=0.5, ny=0.43499999999999994, scale=0.95), 'mouth': FeatureSlot(name='mouth', nx=0.5, ny=0.30499999999999994, scale=1.0), 'facial_hair': FeatureSlot(name='facial_hair', nx=0.5, ny=0.15499999999999994, scale=1.05)}

# %%
# One-at-a-time face layout probe. Change these choices while working on individual draw functions.
face_probe = make_forced_rock(
    rock_id=203,
    choices={
        'shape': 2,
        'size': 0,
        'color': 2,
        'hair': 1,
        'eyes': 1,
        'brows': 3,
        'noses': 2,
        'mouths': 4,
        'facial_hair': 5,
        'hair_color': 2,
    },
    given='Face Probe',
)

fig, ax = plt.subplots(figsize=(5, 5))
machine = drawing.DrawMachine(rock=face_probe, ax=ax)
machine.draw()
print(machine.ctx.presence)
print(machine.ctx.face_layout.slots)
plt.show()
# Out:
# FeaturePresence(eyes=True, brows=True, nose=True, mouth=True, facial_hair=True, hair=True, horns=False, ears=False, crown=False, halo=False, wings=False, tail=False)
# {'brows': FeatureSlot(name='brows', nx=0.5, ny=0.715, scale=0.95), 'eyes': FeatureSlot(name='eyes', nx=0.5, ny=0.575, scale=1.0), 'nose': FeatureSlot(name='nose', nx=0.5, ny=0.44499999999999995, scale=0.95), 'mouth': FeatureSlot(name='mouth', nx=0.5, ny=0.31499999999999995, scale=1.0), 'facial_hair': FeatureSlot(name='facial_hair', nx=0.5, ny=0.16499999999999995, scale=1.05)}
