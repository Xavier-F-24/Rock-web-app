# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Rock_Genetics.rock_genetic_helper import *

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
Lob.genotype = Genome.instantiate_genotype(Rock_gene_dict)
# Out:
# Rock(id=1, name='Lobster Boi', sex=<Sex.MALE: 'male'>, genotype=<Rock_Genetics.rock_genetic_helper.Genome object at 0x0000027B18CCE510>, parent_ids=[], generation=0, status=<RockStatus.ACTIVE: 'active'>, image_path=None, value=None, is_market=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
#       2 print(Lob)
#       3 assert(Lob.sex == Sex.MALE)
# ----> 4 Lob.genotype = Genome.instantiate_genotype(Rock_gene_dict)
#
# File c:\Users\xavie\Desktop\rock_game\Rock_Genetics\rock_genetic_helper.py:307, in Genome.instantiate_genotype(cls, rock_roll_dict)
#     294     allele_b = cls.get_allele_from_roll(
#     295         roll_value = roll_b,
#     296         possible_rolls = possible_rolls,
#    (...)    299         possible_costs = possible_costs,
#     300     )
#     302     genes[gene_name] = GenePair(
#     303         allele_a = allele_a,
#     304         allele_b = allele_b,
#     305     )
# --> 307 return cls(genes = genes)
#
# TypeError: Genome() takes no arguments
