# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Rock_Genetics.rock_genetic_helper import *

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
#Lob.genotype = Genome.instantiate_genotype(Rock_gene_dict)

# %%
GENE_SPECS["arms"].option_for_allele(2)

#GENE_SPECS["eyes"].state_for_key(2)
# Essentially only used for dosage genes!

#GENE_SPECS["arms"].special_states[(0,1)]
#GENE_SPECS["eye_color"].option_for_allele(0)

# %%
a = Allele(0)
b = Allele(1)

dose = 0
dose += 1 if a.value == 1 else 0
dose += 1 if b.value == 1 else 0

dose

# %%
genes = GenomeFactory.make_random_rock_genome(genome_spec_list=GENE_SPECS)
genes

# %%
Rock1 = Rock(
    id=1, 
    name="bruh", 
    sex=Sex.MALE, 
    genotype=GenomeFactory.make_random_rock_genome(
        genome_spec_list=GENE_SPECS)
    )

Rock2 = Rock(
    id=2, 
    name="bruha", 
    sex=Sex.FEMALE, 
    genotype=GenomeFactory.make_random_rock_genome(
        genome_spec_list=GENE_SPECS)
    )

print(Rock1.genotype)
print(Rock1.genotype.genes)

Rock_Child = Rock(
    id=3, 
    name="bruhbruh", 
    sex=Sex.MALE, 
    genotype=GenomeFactory.make_child_rock_genome_from_parents(
        genome_spec_list=GENE_SPECS, 
        parent_a= Rock1, 
        parent_b= Rock2)
    )

Rock_Child.genotype.genes
