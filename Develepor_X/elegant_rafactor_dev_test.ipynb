# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Rock_Genetics.rock_genetic_helper import *

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
#Lob.genotype = Genome.instantiate_genotype(Rock_gene_dict)
# Out:
# Rock(id=1, name='Lobster Boi', sex=<Sex.MALE: 'male'>, genotype=Genome(genes={}), parent_ids=[], generation=0, status=<RockStatus.ACTIVE: 'active'>, image_path=None, value=None, is_market=False)

# %%
GENE_SPECS["arms"].option_for_allele(2)

#GENE_SPECS["eyes"].state_for_key(2)
# Essentially only used for dosage genes!

#GENE_SPECS["arms"].special_states[(0,1)]
#GENE_SPECS["eye_color"].option_for_allele(0)
# Out:
# TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)

# %%
a = Allele(0)
b = Allele(1)

dose = 0
dose += 1 if a.value == 1 else 0
dose += 1 if b.value == 1 else 0

dose
# Out:
# 1

# %%
Genome.instantiate_genotype(genome_spec_list = GENE_SPECS)
# Out:
# instantiating gene shape
# {0: TraitOption(allele=0, roll_threshold=1, name='circle', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='oval', cost=-1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='square', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='triangle', cost=4, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='oblong', cost=-2, dominance=4)}
# roll: 10
# threshold: 0
# 1
# roll: 10
# threshold: 1
# 2
# roll: 10
# threshold: 2
# 3
# roll: 10
# threshold: 3
# 4
# roll: 10
# threshold: 4
# 5
# 4
# {0: TraitOption(allele=0, roll_threshold=1, name='circle', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='oval', cost=-1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='square', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='triangle', cost=4, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='oblong', cost=-2, dominance=4)}
# roll: 4
# threshold: 0
# 1
# roll: 4
# threshold: 1
# 2
# roll: 4
# threshold: 2
# 3
# roll: 4
# threshold: 3
# 4
# roll: 4
# threshold: 4
# 5
# 4
# oblong
# instantiating gene size
# {0: TraitOption(allele=0, roll_threshold=1, name='medium', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='large', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='small', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='giant', cost=4, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='missized', cost=-2, dominance=4)}
# roll: 7
# threshold: 0
# 1
# roll: 7
# threshold: 1
# 2
# roll: 7
# threshold: 2
# 3
# roll: 7
# threshold: 3
# 4
# roll: 7
# threshold: 4
# 5
# 4
# {0: TraitOption(allele=0, roll_threshold=1, name='medium', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='large', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='small', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='giant', cost=4, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='missized', cost=-2, dominance=4)}
# roll: 10
# threshold: 0
# 1
# roll: 10
# threshold: 1
# 2
# roll: 10
# threshold: 2
# 3
# roll: 10
# threshold: 3
# 4
# roll: 10
# threshold: 4
# 5
# 4
# missized
# instantiating gene color
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=11, name='black', cost=0, dominance=0), 2: TraitOption(allele=2, roll_threshold=16, name='brown', cost=1, dominance=1), 3: TraitOption(allele=3, roll_threshold=17, name='red', cost=2, dominance=2), 4: TraitOption(allele=4, roll_threshold=18, name='yellow', cost=2, dominance=2), 5: TraitOption(allele=5, roll_threshold=19, name='blue', cost=2, dominance=2), 6: TraitOption(allele=6, roll_threshold=20, name='patchwork', cost=-1, dominance=3)}
# roll: 12
# threshold: 0
# 1
# roll: 12
# threshold: 1
# 2
# roll: 12
# threshold: 2
# 3
# roll: 12
# threshold: 3
# 4
# roll: 12
# threshold: 4
# 5
# roll: 12
# threshold: 5
# 6
# roll: 12
# threshold: 6
# 7
# 6
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=11, name='black', cost=0, dominance=0), 2: TraitOption(allele=2, roll_threshold=16, name='brown', cost=1, dominance=1), 3: TraitOption(allele=3, roll_threshold=17, name='red', cost=2, dominance=2), 4: TraitOption(allele=4, roll_threshold=18, name='yellow', cost=2, dominance=2), 5: TraitOption(allele=5, roll_threshold=19, name='blue', cost=2, dominance=2), 6: TraitOption(allele=6, roll_threshold=20, name='patchwork', cost=-1, dominance=3)}
# roll: 20
# threshold: 0
# 1
# roll: 20
# threshold: 1
# 2
# roll: 20
# threshold: 2
# 3
# roll: 20
# threshold: 3
# 4
# roll: 20
# threshold: 4
# 5
# roll: 20
# threshold: 5
# 6
# roll: 20
# threshold: 6
# 7
# 6
# patchwork
# instantiating gene eyes
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='active', cost=1, dominance=0)}
# roll: 20
# threshold: 0
# 1
# roll: 20
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='active', cost=1, dominance=0)}
# roll: 16
# threshold: 0
# 1
# roll: 16
# threshold: 1
# 2
# 1
# double eye
# instantiating gene brows
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='brows', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=19, name='eyehair', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=20, name='unibrows', cost=-1, dominance=3)}
# roll: 6
# threshold: 0
# 1
# roll: 6
# threshold: 1
# 2
# roll: 6
# threshold: 2
# 3
# roll: 6
# threshold: 3
# 4
# 3
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='brows', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=19, name='eyehair', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=20, name='unibrows', cost=-1, dominance=3)}
# roll: 5
# threshold: 0
# 1
# roll: 5
# threshold: 1
# 2
# roll: 5
# threshold: 2
# 3
# roll: 5
# threshold: 3
# 4
# 3
# unibrows
# instantiating gene mouths
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='mouth', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='smile', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='chip', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='smeagol', cost=-1, dominance=4)}
# roll: 2
# threshold: 0
# 1
# roll: 2
# threshold: 1
# 2
# roll: 2
# threshold: 2
# 3
# roll: 2
# threshold: 3
# 2
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='mouth', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='smile', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='chip', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='smeagol', cost=-1, dominance=4)}
# roll: 13
# threshold: 0
# 1
# roll: 13
# threshold: 1
# 2
# roll: 13
# threshold: 2
# 3
# roll: 13
# threshold: 3
# 4
# roll: 13
# threshold: 4
# 5
# 4
# smile
# instantiating gene noses
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='nub', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='honk', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='holes', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='concave', cost=-1, dominance=4)}
# roll: 17
# threshold: 0
# 1
# roll: 17
# threshold: 1
# 2
# roll: 17
# threshold: 2
# 3
# roll: 17
# threshold: 3
# 4
# roll: 17
# threshold: 4
# 5
# 4
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='nub', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='honk', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='holes', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='concave', cost=-1, dominance=4)}
# roll: 11
# threshold: 0
# 1
# roll: 11
# threshold: 1
# 2
# roll: 11
# threshold: 2
# 3
# roll: 11
# threshold: 3
# 4
# roll: 11
# threshold: 4
# 5
# 4
# concave
# instantiating gene arms
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=19, name='arms', cost=1, dominance=0), 2: TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)}
# roll: 12
# threshold: 0
# 1
# roll: 12
# threshold: 1
# 2
# roll: 12
# threshold: 2
# 3
# 2
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=19, name='arms', cost=1, dominance=0), 2: TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)}
# roll: 11
# threshold: 0
# 1
# roll: 11
# threshold: 1
# 2
# roll: 11
# threshold: 2
# 3
# 2
# muscle arms
# instantiating gene crowns
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='small', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='medium', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='large', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='indent', cost=-1, dominance=4)}
# roll: 7
# threshold: 0
# 1
# roll: 7
# threshold: 1
# 2
# roll: 7
# threshold: 2
# 3
# roll: 7
# threshold: 3
# 4
# roll: 7
# threshold: 4
# 5
# 4
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='small', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='medium', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='large', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='indent', cost=-1, dominance=4)}
# roll: 3
# threshold: 0
# 1
# roll: 3
# threshold: 1
# 2
# roll: 3
# threshold: 2
# 3
# roll: 3
# threshold: 3
# 4
# roll: 3
# threshold: 4
# 3
# large
# instantiating gene wings
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='wings', cost=2, dominance=1)}
# roll: 2
# threshold: 0
# 1
# roll: 2
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='wings', cost=2, dominance=1)}
# roll: 9
# threshold: 0
# 1
# roll: 9
# threshold: 1
# 2
# 1
# wings
# instantiating gene halos
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='halos', cost=2, dominance=1)}
# roll: 9
# threshold: 0
# 1
# roll: 9
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='halos', cost=2, dominance=1)}
# roll: 11
# threshold: 0
# 1
# roll: 11
# threshold: 1
# 2
# 1
# halos
# instantiating gene horns
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='horns', cost=2, dominance=1)}
# roll: 5
# threshold: 0
# 1
# roll: 5
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='horns', cost=2, dominance=1)}
# roll: 15
# threshold: 0
# 1
# roll: 15
# threshold: 1
# 2
# 1
# horns
# instantiating gene wrinkles
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='wrinkles', cost=2, dominance=1)}
# roll: 1
# threshold: 0
# 1
# roll: 1
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='wrinkles', cost=2, dominance=1)}
# roll: 1
# threshold: 0
# 1
# roll: 1
# threshold: 1
# 2
# 1
# wrinkles
# instantiating gene fuzz
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='active', cost=1, dominance=1)}
# roll: 2
# threshold: 0
# 1
# roll: 2
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='active', cost=1, dominance=1)}
# roll: 16
# threshold: 0
# 1
# roll: 16
# threshold: 1
# 2
# 1
# spiky
# instantiating gene hair
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='active', cost=1, dominance=1)}
# roll: 19
# threshold: 0
# 1
# roll: 19
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='inactive', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=18, name='active', cost=1, dominance=1)}
# roll: 9
# threshold: 0
# 1
# roll: 9
# threshold: 1
# 2
# 1
# double hair
# instantiating gene facial_hair
# {0: TraitOption(allele=0, roll_threshold=0, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=15, name='goatee', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=16, name='beard', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=17, name='pedo', cost=-1, dominance=3), 4: TraitOption(allele=4, roll_threshold=18, name='curly', cost=3, dominance=4), 5: TraitOption(allele=5, roll_threshold=19, name='chapman', cost=4, dominance=5), 6: TraitOption(allele=6, roll_threshold=20, name='sol', cost=-2, dominance=6)}
# roll: 2
# threshold: 0
# 1
# roll: 2
# threshold: 1
# 2
# roll: 2
# threshold: 2
# 3
# roll: 2
# threshold: 3
# 2
# {0: TraitOption(allele=0, roll_threshold=0, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=15, name='goatee', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=16, name='beard', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=17, name='pedo', cost=-1, dominance=3), 4: TraitOption(allele=4, roll_threshold=18, name='curly', cost=3, dominance=4), 5: TraitOption(allele=5, roll_threshold=19, name='chapman', cost=4, dominance=5), 6: TraitOption(allele=6, roll_threshold=20, name='sol', cost=-2, dominance=6)}
# roll: 9
# threshold: 0
# 1
# roll: 9
# threshold: 1
# 2
# roll: 9
# threshold: 2
# 3
# roll: 9
# threshold: 3
# 4
# roll: 9
# threshold: 4
# 5
# roll: 9
# threshold: 5
# 6
# roll: 9
# threshold: 6
# 7
# 6
# beard
# instantiating gene freckles
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='freckles', cost=2, dominance=1)}
# roll: 15
# threshold: 0
# 1
# roll: 15
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='freckles', cost=2, dominance=1)}
# roll: 6
# threshold: 0
# 1
# roll: 6
# threshold: 1
# 2
# 1
# freckles
# instantiating gene stones
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='stones', cost=2, dominance=1)}
# roll: 5
# threshold: 0
# 1
# roll: 5
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='stones', cost=2, dominance=1)}
# roll: 18
# threshold: 0
# 1
# roll: 18
# threshold: 1
# 2
# 1
# stones
# instantiating gene tails
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='tails', cost=2, dominance=1)}
# roll: 4
# threshold: 0
# 1
# roll: 4
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='tails', cost=2, dominance=1)}
# roll: 4
# threshold: 0
# 1
# roll: 4
# threshold: 1
# 2
# 1
# tails
# instantiating gene eye_color
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=13, name='black', cost=1, dominance=0), 2: TraitOption(allele=2, roll_threshold=14, name='red', cost=2, dominance=1), 3: TraitOption(allele=3, roll_threshold=15, name='green', cost=3, dominance=2), 4: TraitOption(allele=4, roll_threshold=16, name='blue', cost=4, dominance=3), 5: TraitOption(allele=5, roll_threshold=17, name='yellow', cost=5, dominance=4), 6: TraitOption(allele=6, roll_threshold=18, name='evil', cost=-1, dominance=5), 7: TraitOption(allele=7, roll_threshold=19, name='purple', cost=6, dominance=6), 8: TraitOption(allele=8, roll_threshold=20, name='callus', cost=-3, dominance=7)}
# roll: 11
# threshold: 0
# 1
# roll: 11
# threshold: 1
# 2
# roll: 11
# threshold: 2
# 3
# roll: 11
# threshold: 3
# 4
# roll: 11
# threshold: 4
# 5
# roll: 11
# threshold: 5
# 6
# roll: 11
# threshold: 6
# 7
# roll: 11
# threshold: 7
# 8
# roll: 11
# threshold: 8
# 9
# 8
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=13, name='black', cost=1, dominance=0), 2: TraitOption(allele=2, roll_threshold=14, name='red', cost=2, dominance=1), 3: TraitOption(allele=3, roll_threshold=15, name='green', cost=3, dominance=2), 4: TraitOption(allele=4, roll_threshold=16, name='blue', cost=4, dominance=3), 5: TraitOption(allele=5, roll_threshold=17, name='yellow', cost=5, dominance=4), 6: TraitOption(allele=6, roll_threshold=18, name='evil', cost=-1, dominance=5), 7: TraitOption(allele=7, roll_threshold=19, name='purple', cost=6, dominance=6), 8: TraitOption(allele=8, roll_threshold=20, name='callus', cost=-3, dominance=7)}
# roll: 10
# threshold: 0
# 1
# roll: 10
# threshold: 1
# 2
# roll: 10
# threshold: 2
# 3
# roll: 10
# threshold: 3
# 4
# roll: 10
# threshold: 4
# 5
# roll: 10
# threshold: 5
# 6
# roll: 10
# threshold: 6
# 7
# roll: 10
# threshold: 7
# 8
# roll: 10
# threshold: 8
# 9
# 8
# callus
# instantiating gene hair_color
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=11, name='black', cost=0, dominance=0), 2: TraitOption(allele=2, roll_threshold=16, name='brown', cost=1, dominance=1), 3: TraitOption(allele=3, roll_threshold=17, name='blonde', cost=2, dominance=2), 4: TraitOption(allele=4, roll_threshold=18, name='red', cost=3, dominance=3), 5: TraitOption(allele=5, roll_threshold=19, name='pink', cost=-1, dominance=4), 6: TraitOption(allele=6, roll_threshold=20, name='blue', cost=-2, dominance=5)}
# roll: 16
# threshold: 0
# 1
# roll: 16
# threshold: 1
# 2
# roll: 16
# threshold: 2
# 3
# roll: 16
# threshold: 3
# 4
# roll: 16
# threshold: 4
# 5
# roll: 16
# threshold: 5
# 6
# roll: 16
# threshold: 6
# 7
# 6
# {0: TraitOption(allele=0, roll_threshold=1, name='white', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=11, name='black', cost=0, dominance=0), 2: TraitOption(allele=2, roll_threshold=16, name='brown', cost=1, dominance=1), 3: TraitOption(allele=3, roll_threshold=17, name='blonde', cost=2, dominance=2), 4: TraitOption(allele=4, roll_threshold=18, name='red', cost=3, dominance=3), 5: TraitOption(allele=5, roll_threshold=19, name='pink', cost=-1, dominance=4), 6: TraitOption(allele=6, roll_threshold=20, name='blue', cost=-2, dominance=5)}
# roll: 18
# threshold: 0
# 1
# roll: 18
# threshold: 1
# 2
# roll: 18
# threshold: 2
# 3
# roll: 18
# threshold: 3
# 4
# roll: 18
# threshold: 4
# 5
# roll: 18
# threshold: 5
# 6
# roll: 18
# threshold: 6
# 7
# 6
# blue
# instantiating gene ears
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='antannae', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='ears', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='ogre', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='goblin', cost=-1, dominance=4)}
# roll: 4
# threshold: 0
# 1
# roll: 4
# threshold: 1
# 2
# roll: 4
# threshold: 2
# 3
# roll: 4
# threshold: 3
# 4
# roll: 4
# threshold: 4
# 5
# 4
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=17, name='antannae', cost=1, dominance=1), 2: TraitOption(allele=2, roll_threshold=18, name='ears', cost=2, dominance=2), 3: TraitOption(allele=3, roll_threshold=19, name='ogre', cost=3, dominance=3), 4: TraitOption(allele=4, roll_threshold=20, name='goblin', cost=-1, dominance=4)}
# roll: 15
# threshold: 0
# 1
# roll: 15
# threshold: 1
# 2
# roll: 15
# threshold: 2
# 3
# roll: 15
# threshold: 3
# 4
# roll: 15
# threshold: 4
# 5
# 4
# goblin
# instantiating gene hair_texture
# {0: TraitOption(allele=0, roll_threshold=1, name='straight', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='curly', cost=2, dominance=1)}
# roll: 10
# threshold: 0
# 1
# roll: 10
# threshold: 1
# 2
# 1
# {0: TraitOption(allele=0, roll_threshold=1, name='straight', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=20, name='curly', cost=2, dominance=1)}
# roll: 3
# threshold: 0
# 1
# roll: 3
# threshold: 1
# 2
# 1
# curly
# instantiating gene splitting
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=19, name='mitosion', cost=0, dominance=1), 2: TraitOption(allele=2, roll_threshold=20, name='spore', cost=0, dominance=2)}
# roll: 12
# threshold: 0
# 1
# roll: 12
# threshold: 1
# 2
# roll: 12
# threshold: 2
# 3
# 2
# {0: TraitOption(allele=0, roll_threshold=1, name='n/a', cost=0, dominance=0), 1: TraitOption(allele=1, roll_threshold=19, name='mitosion', cost=0, dominance=1), 2: TraitOption(allele=2, roll_threshold=20, name='spore', cost=0, dominance=2)}
# roll: 7
# threshold: 0
# 1
# roll: 7
# threshold: 1
# 2
# roll: 7
# threshold: 2
# 3
# 2
# spore
# Genome(genes={'shape': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='shape', dominance_type='dominance', money_value=-2, phenotype='oblong'), 'size': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='size', dominance_type='dominance', money_value=-2, phenotype='missized'), 'color': GenePair(allele_a=Allele(value=6), allele_b=Allele(value=6), name_of_gene='color', dominance_type='body_color_dominance', money_value=-1, phenotype='patchwork'), 'eyes': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='eyes', dominance_type='dosage', money_value=2, phenotype='double eye'), 'brows': GenePair(allele_a=Allele(value=3), allele_b=Allele(value=3), name_of_gene='brows', dominance_type='dominance', money_value=-1, phenotype='unibrows'), 'mouths': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=4), name_of_gene='mouths', dominance_type='dominance', money_value=2, phenotype='smile'), 'noses': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='noses', dominance_type='dominance', money_value=-1, phenotype='concave'), 'arms': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=2), name_of_gene='arms', dominance_type='arms_dominance', money_value=2, phenotype='muscle arms'), 'crowns': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=3), name_of_gene='crowns', dominance_type='dominance', money_value=3, phenotype='large'), 'wings': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='wings', dominance_type='dominance', money_value=2, phenotype='wings'), 'halos': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='halos', dominance_type='dominance', money_value=2, phenotype='halos'), 'horns': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='horns', dominance_type='dominance', money_value=2, phenotype='horns'), 'wrinkles': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='wrinkles', dominance_type='dominance', money_value=2, phenotype='wrinkles'), 'fuzz': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='fuzz', dominance_type='dosage', money_value=2, phenotype='spiky'), 'hair': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='hair', dominance_type='dosage', money_value=2, phenotype='double hair'), 'facial_hair': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=6), name_of_gene='facial_hair', dominance_type='dominance', money_value=2, phenotype='beard'), 'freckles': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='freckles', dominance_type='dominance', money_value=2, phenotype='freckles'), 'stones': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='stones', dominance_type='dominance', money_value=2, phenotype='stones'), 'tails': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='tails', dominance_type='dominance', money_value=2, phenotype='tails'), 'eye_color': GenePair(allele_a=Allele(value=8), allele_b=Allele(value=8), name_of_gene='eye_color', dominance_type='dominance', money_value=-3, phenotype='callus'), 'hair_color': GenePair(allele_a=Allele(value=6), allele_b=Allele(value=6), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=-2, phenotype='blue'), 'ears': GenePair(allele_a=Allele(value=4), allele_b=Allele(value=4), name_of_gene='ears', dominance_type='dominance', money_value=-1, phenotype='goblin'), 'hair_texture': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=1), name_of_gene='hair_texture', dominance_type='dominance', money_value=2, phenotype='curly'), 'splitting': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=2), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype='spore')})
