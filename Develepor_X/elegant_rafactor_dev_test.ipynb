# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)

from Rock_Genetics.rock_genetic_helper import *
# Out:
# c:\Users\xavie\Desktop\rock_game

# %%
Lob = Rock(id = 1, name = "Lobster Boi", sex = Sex.MALE)
print(Lob)
assert(Lob.sex == Sex.MALE)
# Out:
# Rock(id=1, name='Lobster Boi', sex=<Sex.MALE: 'male'>, genotype=Genome(genes={}), death_genes=Genome(genes={}), parent_ids=[], generation=0, status=<RockStatus.ACTIVE: 'active'>, has_split=False, death_reason=None, image_path=None, value=0, sell_value=0, score_value=0, is_market=False)

# %%
GENE_SPECS["arms"].option_for_allele(2)

#GENE_SPECS["eyes"].state_for_key(2)
# Essentially only used for dosage genes!

#GENE_SPECS["arms"].special_states[(0,1)]
#GENE_SPECS["eye_color"].option_for_allele(0)
# Out:
# TraitOption(allele=2, roll_threshold=20, name='muscle arms', cost=2, dominance=0)

# %%
factorio = GenomeFactory()
espresso = ExpressionEngine()
valuo = ValueCalculator()

Rock1 = Rock(
    id=1, 
    name="bruh", 
    sex=Sex.MALE, 
    genotype=factorio.make_random_rock_genome(),
    death_genes= factorio.make_death_genes(),
    )

Rock2 = Rock(
    id=2, 
    name="bruha", 
    sex=Sex.FEMALE, 
    genotype=factorio.make_random_rock_genome(),
    death_genes= factorio.make_death_genes(),
)

print(Rock1.genotype)
print(Rock1.genotype.genes)

#Rock1 = espresso.instantiate_phenotype(rock=Rock1, genome_spec_list=GENE_SPECS)

#print(Rock1)

#Rock1 = valuo.set_rock_value(rock=Rock1,genome_spec_list=GENE_SPECS)

#print(Rock1)


Rock_Child = valuo.set_rock_value(
    rock = espresso.instantiate_phenotype(
        rock = Rock(
            id = 3, 
            name = "bruhbruh", 
            sex = Sex.MALE, 
            genotype = factorio.make_child_rock_genome_from_parents(
                parent_a = Rock1, 
                parent_b = Rock2
                )
            )
        )
    )


print(Rock_Child.genotype.print_genes())
# Out:
# Genome(genes={'shape': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='shape', dominance_type='dominance', money_value=0, phenotype=None), 'size': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='size', dominance_type='dominance', money_value=0, phenotype=None), 'color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=4), name_of_gene='color', dominance_type='body_color_dominance', money_value=0, phenotype=None), 'eyes': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eyes', dominance_type='dosage', money_value=0, phenotype=None), 'brows': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=3), name_of_gene='brows', dominance_type='dominance', money_value=0, phenotype=None), 'mouths': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='mouths', dominance_type='dominance', money_value=0, phenotype=None), 'noses': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='noses', dominance_type='dominance', money_value=0, phenotype=None), 'arms': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='arms', dominance_type='arms_dominance', money_value=0, phenotype=None), 'crowns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='crowns', dominance_type='dominance', money_value=0, phenotype=None), 'wings': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wings', dominance_type='dominance', money_value=0, phenotype=None), 'halos': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='halos', dominance_type='dominance', money_value=0, phenotype=None), 'horns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='horns', dominance_type='dominance', money_value=0, phenotype=None), 'wrinkles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=1), name_of_gene='wrinkles', dominance_type='dominance', money_value=0, phenotype=None), 'fuzz': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='fuzz', dominance_type='dosage', money_value=0, phenotype=None), 'hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair', dominance_type='dosage', money_value=0, phenotype=None), 'facial_hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='facial_hair', dominance_type='dominance', money_value=0, phenotype=None), 'freckles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='freckles', dominance_type='dominance', money_value=0, phenotype=None), 'stones': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='stones', dominance_type='dominance', money_value=0, phenotype=None), 'tails': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='tails', dominance_type='dominance', money_value=0, phenotype=None), 'eye_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=1), name_of_gene='eye_color', dominance_type='dominance', money_value=0, phenotype=None), 'hair_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=6), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=0, phenotype=None), 'ears': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='ears', dominance_type='dominance', money_value=0, phenotype=None), 'hair_texture': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_texture', dominance_type='dominance', money_value=0, phenotype=None), 'splitting': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype=None)})
# {'shape': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='shape', dominance_type='dominance', money_value=0, phenotype=None), 'size': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='size', dominance_type='dominance', money_value=0, phenotype=None), 'color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=4), name_of_gene='color', dominance_type='body_color_dominance', money_value=0, phenotype=None), 'eyes': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eyes', dominance_type='dosage', money_value=0, phenotype=None), 'brows': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=3), name_of_gene='brows', dominance_type='dominance', money_value=0, phenotype=None), 'mouths': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='mouths', dominance_type='dominance', money_value=0, phenotype=None), 'noses': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='noses', dominance_type='dominance', money_value=0, phenotype=None), 'arms': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='arms', dominance_type='arms_dominance', money_value=0, phenotype=None), 'crowns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='crowns', dominance_type='dominance', money_value=0, phenotype=None), 'wings': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wings', dominance_type='dominance', money_value=0, phenotype=None), 'halos': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='halos', dominance_type='dominance', money_value=0, phenotype=None), 'horns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='horns', dominance_type='dominance', money_value=0, phenotype=None), 'wrinkles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=1), name_of_gene='wrinkles', dominance_type='dominance', money_value=0, phenotype=None), 'fuzz': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='fuzz', dominance_type='dosage', money_value=0, phenotype=None), 'hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair', dominance_type='dosage', money_value=0, phenotype=None), 'facial_hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='facial_hair', dominance_type='dominance', money_value=0, phenotype=None), 'freckles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='freckles', dominance_type='dominance', money_value=0, phenotype=None), 'stones': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='stones', dominance_type='dominance', money_value=0, phenotype=None), 'tails': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='tails', dominance_type='dominance', money_value=0, phenotype=None), 'eye_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=1), name_of_gene='eye_color', dominance_type='dominance', money_value=0, phenotype=None), 'hair_color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=6), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=0, phenotype=None), 'ears': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='ears', dominance_type='dominance', money_value=0, phenotype=None), 'hair_texture': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_texture', dominance_type='dominance', money_value=0, phenotype=None), 'splitting': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='splitting', dominance_type='dominance', money_value=0, phenotype=None)}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 39
#      35         rock = Rock(
#      36             id = 3,
#      37             name = "bruhbruh",
#      38             sex = Sex.MALE,
# ---> 39             genotype = factorio.make_child_rock_genome_from_parents(
#      40                 parent_a = Rock1,
#      41                 parent_b = Rock2
#      42                 )
#
# TypeError: GenomeFactory.make_child_rock_genome_from_parents() missing 1 required positional argument: 'mutation_chance'

# %%
print(Rock1.death_genes.genes)
print(Rock2.death_genes.genes)

Rock_Child = valuo.set_rock_value(
    rock = espresso.instantiate_phenotype(
        rock = Rock(
            id = 3, 
            name = "bruhbruh", 
            sex = Sex.MALE, 
            genotype = factorio.make_child_rock_genome_from_parents(
                parent_a = Rock1, 
                parent_b = Rock2
                ),
            death_genes = factorio.inherit_death_genes(
                parent_a= Rock1,
                parent_b= Rock2,
            ),
            )
        )
    )

Rock_Child.death_genes.genes
# Out:
# {'death_gene1': GenePair(allele_a=Allele(value=14), allele_b=Allele(value=31), name_of_gene='death_gene1', dominance_type='death_genes', money_value=None, phenotype=None), 'death_gene2': GenePair(allele_a=Allele(value=51), allele_b=Allele(value=13), name_of_gene='death_gene2', dominance_type='death_genes', money_value=None, phenotype=None), 'death_gene3': GenePair(allele_a=Allele(value=18), allele_b=Allele(value=69), name_of_gene='death_gene3', dominance_type='death_genes', money_value=None, phenotype=None)}
# {'death_gene1': GenePair(allele_a=Allele(value=73), allele_b=Allele(value=86), name_of_gene='death_gene1', dominance_type='death_genes', money_value=None, phenotype=None), 'death_gene2': GenePair(allele_a=Allele(value=91), allele_b=Allele(value=83), name_of_gene='death_gene2', dominance_type='death_genes', money_value=None, phenotype=None), 'death_gene3': GenePair(allele_a=Allele(value=66), allele_b=Allele(value=99), name_of_gene='death_gene3', dominance_type='death_genes', money_value=None, phenotype=None)}
# {'death_gene1': GenePair(allele_a=Allele(value=14), allele_b=Allele(value=86), name_of_gene='death_gene1', dominance_type='death_genes', money_value=None, phenotype=None),
#  'death_gene2': GenePair(allele_a=Allele(value=13), allele_b=Allele(value=83), name_of_gene='death_gene2', dominance_type='death_genes', money_value=None, phenotype=None),
#  'death_gene3': GenePair(allele_a=Allele(value=69), allele_b=Allele(value=99), name_of_gene='death_gene3', dominance_type='death_genes', money_value=None, phenotype=None)}

# %%
Rock1.change_status(new_status= RockStatus.BRED)
Rock1
# Out:
# Rock(id=1, name='bruh', sex=<Sex.MALE: 'male'>, genotype=Genome(genes={'shape': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='shape', dominance_type='dominance', money_value=None, phenotype=None), 'size': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=1), name_of_gene='size', dominance_type='dominance', money_value=None, phenotype=None), 'color': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='color', dominance_type='body_color_dominance', money_value=None, phenotype=None), 'eyes': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='eyes', dominance_type='dosage', money_value=None, phenotype=None), 'brows': GenePair(allele_a=Allele(value=1), allele_b=Allele(value=0), name_of_gene='brows', dominance_type='dominance', money_value=None, phenotype=None), 'mouths': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='mouths', dominance_type='dominance', money_value=None, phenotype=None), 'noses': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='noses', dominance_type='dominance', money_value=None, phenotype=None), 'arms': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='arms', dominance_type='arms_dominance', money_value=None, phenotype=None), 'crowns': GenePair(allele_a=Allele(value=3), allele_b=Allele(value=2), name_of_gene='crowns', dominance_type='dominance', money_value=None, phenotype=None), 'wings': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wings', dominance_type='dominance', money_value=None, phenotype=None), 'halos': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='halos', dominance_type='dominance', money_value=None, phenotype=None), 'horns': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='horns', dominance_type='dominance', money_value=None, phenotype=None), 'wrinkles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='wrinkles', dominance_type='dominance', money_value=None, phenotype=None), 'fuzz': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='fuzz', dominance_type='dosage', money_value=None, phenotype=None), 'hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair', dominance_type='dosage', money_value=None, phenotype=None), 'facial_hair': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='facial_hair', dominance_type='dominance', money_value=None, phenotype=None), 'freckles': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='freckles', dominance_type='dominance', money_value=None, phenotype=None), 'stones': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='stones', dominance_type='dominance', money_value=None, phenotype=None), 'tails': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='tails', dominance_type='dominance', money_value=None, phenotype=None), 'eye_color': GenePair(allele_a=Allele(value=7), allele_b=Allele(value=0), name_of_gene='eye_color', dominance_type='dominance', money_value=None, phenotype=None), 'hair_color': GenePair(allele_a=Allele(value=2), allele_b=Allele(value=1), name_of_gene='hair_color', dominance_type='hair_color_codominance', money_value=None, phenotype=None), 'ears': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='ears', dominance_type='dominance', money_value=None, phenotype=None), 'hair_texture': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='hair_texture', dominance_type='dominance', money_value=None, phenotype=None), 'splitting': GenePair(allele_a=Allele(value=0), allele_b=Allele(value=0), name_of_gene='splitting', dominance_type='dominance', money_value=None, phenotype=None)}), death_genes=Genome(genes={'death_gene1': GenePair(allele_a=Allele(value=14), allele_b=Allele(value=31), name_of_gene='death_gene1 ...

# %%
spore_clone_count = 4
for spore_clone in range(1 + spore_clone_count):
    print(spore_clone)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
spores = 4
for spo in range(spores):
    print(spo)
# Out:
# 0
# 1
# 2
# 3

# %%
child_bred_in_generation = [1,2,3]

new_id = 0

if child_bred_in_generation:
    new_id = 1 + len(child_bred_in_generation)

print(new_id)
print(type(new_id))
# Out:
# 4
# <class 'int'>

# %%
child_bred_in_generation = [1]

print(len(child_bred_in_generation))
# Out:
# 1

# %%
list_cho =[]

spore_maybe = random.randint(1,4)

for cho in range(spore_maybe):
    list_cho.append(random.choice([Rock1.id, Rock2.id]))

print(list_cho)
bro_list = []

if len(list_cho) > 1:   
    list_cho.pop(0)
    for spo in list_cho:
        bro_list.append(spo)


print(bro_list)
# Out:
# [2]
# []
